# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_excel("HeartDisease.xlsx")
ds
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     63    1   4      140  260   0        1     112     1       3     2  ?
# 1     44    1   4      130  209   0        1     127     0       0     ?  ?
# 2     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4     66    1   3      110  213   1        2      99     1     1.3     2  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 195   54    0   4      127  333   1        1     154     0       0     ?  ?
# 196   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 197   55    1   4      122  223   1        1     100     0       0     ?  ?
# 198   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 199   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    2
# 1      ?    0
# ...

# %%
ds.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
ds.shape
# Out:
# (200, 14)

# %%
ds.dtypes
# Out:
# age          int64
# sex          int64
# cp           int64
# trestbps    object
# chol        object
# fbs         object
# restecg      int64
# thalach     object
# exang       object
# oldpeak     object
# slope       object
# ca          object
# thal        object
# num          int64
# dtype: object

# %%
ds['trestbps'].value_counts()
# Out:
# ?      56
# 120    16
# 130    15
# 140    10
# 150     9
# 110     9
# 160     8
# 122     6
# 142     5
# 170     4
# 128     4
# 126     4
# 136     4
# 144     4
# 134     4
# 124     4
# 158     3
# 132     3
# 180     2
# 138     2
# 112     2
# 155     2
# 154     2
# 152     2
# 116     2
# 125     2
# 104     2
# 114     1
# 135     1
# 100     1
# 127     1
# 146     1
# 156     1
# 106     1
# 190     1
# 102     1
# 172     1
# 96      1
# 178     1
# 118     1
# 0       1
# Name: trestbps, dtype: int64

# %%
ds.replace({'trestbps':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['chol'].value_counts()
# Out:
# 0      49
# ?       7
# 258     4
# 203     4
# 220     4
#        ..
# 177     1
# 181     1
# 182     1
# 243     1
# 142     1
# Name: chol, Length: 100, dtype: int64

# %%
ds.replace({'chol':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['fbs'].value_counts()
# Out:
# 0    125
# 1     68
# ?      7
# Name: fbs, dtype: int64

# %%
ds.replace({'fbs':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['thalach'].value_counts()
# Out:
# ?      53
# 140    12
# 120    12
# 110     8
# 130     6
# 112     6
# 128     4
# 118     4
# 100     4
# 160     4
# 150     4
# 105     4
# 86      3
# 106     3
# 148     3
# 102     3
# 135     3
# 84      3
# 108     3
# 125     3
# 122     3
# 117     3
# 127     2
# 138     2
# 98      2
# 119     2
# 165     2
# 180     2
# 80      2
# 96      2
# 129     2
# 111     2
# 154     2
# 124     1
# 123     1
# 151     1
# 141     1
# 144     1
# 133     1
# 145     1
# 132     1
# 131     1
# 149     1
# 121     1
# 107     1
# 155     1
# 157     1
# 161     1
# 162     1
# 69      1
# 73      1
# 126     1
# 88      1
# 93      1
# 94      1
# 97      1
# 115     1
# 99      1
# 113     1
# 159     1
# Name: thalach, dtype: int64

# %%
ds.replace({'thalach':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['exang'].value_counts()
# Out:
# 1    95
# ?    53
# 0    52
# Name: exang, dtype: int64

# %%
ds.replace({'exang':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['oldpeak'].value_counts()
# Out:
# ?       56
# 0       40
# 2       25
# 1.5     21
# 1       18
# 3       13
# 2.5      9
# 0.5      7
# 4        4
# 1.3      2
# 1.7      1
# 3.5      1
# 1.6      1
# 0.8      1
# -0.5     1
# Name: oldpeak, dtype: int64

# %%
ds.replace({'oldpeak':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['slope'].value_counts()
# Out:
# ?    102
# 2     53
# 3     29
# 1     16
# Name: slope, dtype: int64

# %%
ds.replace({'slope':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['ca'].value_counts()
# Out:
# ?    198
# 0      2
# Name: ca, dtype: int64

# %%
ds.replace({'ca':{'?':np.nan}},regex=False,inplace=True)

# %%
ds['thal'].value_counts()
# Out:
# ?    166
# 7     22
# 6      8
# 3      4
# Name: thal, dtype: int64

# %%
ds.replace({'thal':{'?':np.nan}},regex=False,inplace=True)

# %%
ds.shape
# Out:
# (200, 14)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       200 non-null    int64
#  1   sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trestbps  144 non-null    float64
#  4   chol      193 non-null    float64
#  5   fbs       193 non-null    float64
#  6   restecg   200 non-null    int64
#  7   thalach   147 non-null    float64
#  8   exang     147 non-null    float64
#  9   oldpeak   144 non-null    float64
#  10  slope     98 non-null     float64
#  11  ca        2 non-null      float64
#  12  thal      34 non-null     float64
#  13  num       200 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 22.0 KB

# %%
ds.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps     56
# chol          7
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          198
# thal        166
# num           0
# dtype: int64

# %% [markdown]
# Observation:
#
#     In the columns slope, ca, thal more than 50% of data is missing so we can drope those columns.
#     Lets see it clearly with the help of visualization.

# %%
plt.subplots(figsize=(12,4))
sns.heatmap(ds.isnull(),annot=True)
plt.show()

# %% [markdown]
# Observation:
#
#     In the columns slope, ca and thal we can see that majority of the data is missing.

# %%
sns.countplot(ds['num'])

# %% [markdown]
# Observation:
#
#     There are 5 levels of heart disease present in our dataset.
#
#     More than 55 people are suffering from level 1 heart disease.

# %%
plt.subplots(figsize=(12,4))
sns.countplot(ds['age'])

# %% [markdown]
# Observation:
#
#     Majority of the people fall in the age range of 62-63 years.

# %%
sns.countplot(ds['ca'])

# %% [markdown]
# Observation:
#
#     Almost all of the data is missing from this column.

# %%
plt.subplots(figsize=(30,14))
sns.countplot(ds['thalach'])

# %% [markdown]
# Observation:
#
#     Majority of the people have thalach rate of 120.

# %%
sns.set(style='whitegrid')
sns.violinplot(ds['trestbps'])
plt.show()

# %% [markdown]
# Observation:
#
#     Majority of the people have trestbps between 130-150.

# %%
sns.set(style='whitegrid')
sns.violinplot(ds['cp'])
plt.show()

# %% [markdown]
# observation:
#
#     Majority of the people have cp between 3-4.

# %%
sns.set(style='white')
plt.scatter(ds['cp'],ds['thalach'])
plt.xlabel('No of cp')
plt.ylabel('thalach')
plt.title("Scatter plot of No of cp vs thalach")
plt.show()

# %% [markdown]
# Observation:
#
#     If the no. of cp is 3 the level of thalach is maximum.

# %%
sns.set(style='white')
plt.scatter(ds['chol'],ds['restecg'])
plt.xlabel('chol')
plt.ylabel('restecg')
plt.title("Scatter plot of chol vs restecg")
plt.show()

# %% [markdown]
# observation:
#
#     If the no. of chol is between 200-300 maximum no. of restecg has been observed.

# %%
sns.barplot(x='sex',y='num',data=ds)
plt.xticks()
plt.show()

# %% [markdown]
# Observation:
#
#     people with sex 1 have the maximum num level of heart disease.

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='age',y='num',data=ds)
plt.xticks()
plt.show()

# %% [markdown]
# Observation:
#
#     Maximum no. of num level  has been observed in people of the age range of 76.

# %%
plt.figure(figsize=(14,14))
sns.barplot(x='num',y='chol',data=ds)
plt.xticks()
plt.show()

# %% [markdown]
# observation:
#
#     Maximum level of chol has been observed with people of num level 4.

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='trestbps',y='num',data=ds)
plt.xticks()
plt.show()

# %% [markdown]
# Observation:
#
#     The highesh level of trestbps i.e 90.0 has been observed with people of num level 4.

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='trestbps',y='chol',data=ds)
plt.xticks()
plt.show()

# %% [markdown]
# Observation:
#
#     The highest level of trestbps has been observed with people of chol level 320.

# %%
ds_cor=ds.corr()
ds_cor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.034230 -0.038280  0.210980  0.069138  0.127817
# sex       0.034230  1.000000  0.038036  0.013820 -0.096204 -0.055372
# cp       -0.038280  0.038036  1.000000  0.097246  0.066279 -0.047701
# trestbps  0.210980  0.013820  0.097246  1.000000  0.176922  0.226024
# chol      0.069138 -0.096204  0.066279  0.176922  1.000000  0.160850
# fbs       0.127817 -0.055372 -0.047701  0.226024  0.160850  1.000000
# restecg   0.002400  0.060621  0.034790  0.106918  0.025154  0.167657
# thalach  -0.174125 -0.001747 -0.160306 -0.013177 -0.048269  0.061682
# exang     0.156823  0.018155  0.235935  0.222550  0.102016 -0.259299
# oldpeak   0.183086  0.106811  0.055933  0.118022  0.001549 -0.122122
# slope     0.148603  0.124613  0.047762  0.109788  0.080450  0.023457
# ca             NaN       NaN       NaN       NaN       NaN       NaN
# thal      0.176430 -0.138675  0.213339  0.230130 -0.171315  0.059924
# ...

# %% [markdown]
# Here we can see the correlation between the columns.
#
# For better understanding we can see it via visualization with the help of heatmap.

# %%
plt.figure(figsize=(25,15))
sns.heatmap(ds_cor,annot=True,cmap='winter')

# %% [markdown]
# Observation:
#
#     1. num, slope is highly positively correlated with oldpeak.
#
#     2. exang is highly positively correlated with oldpeak.
#
#     3. sex, chol and thalach is negatively correlated with thal.

# %%
ds.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  200.000000  200.000000  200.000000  144.000000  193.000000  193.000000
# mean    59.350000    0.970000    3.505000  133.763889  178.746114    0.352332
# std      7.811697    0.171015    0.795701   21.537733  114.035232    0.478939
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  216.000000    0.000000
# 75%     64.000000    1.000000    4.000000  147.000000  258.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak      slope   ca  \
# count  200.000000  147.000000  147.000000  144.000000  98.000000  2.0
# mean     0.735000  122.795918    0.646259    1.320833   2.132653  0.0
# ...

# %% [markdown]
# Observation:
#
#     1. Standard deviation is maximum in restecg followed by slope.
#
#     2. Minimum age of a person is 35 and maximum is 77.
#
#     3. In chol, thalach the difference between 75% and maximum is more so outliers maybe present there.

# %%
plt.figure(figsize=(18,14))

for i in range(len(ds.columns)):
        plt.subplot(7,2,i+1)
        plt.boxplot(ds[ds.columns[i]], vert=False)
        plt.title(ds.columns[i])
plt.show()

# %%
ds.shape
# Out:
# (200, 14)

# %%
collist=ds.columns.values
ncol=14
nrow=10

# %%
plt.figure(figsize=(14,14))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(ds[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
for i in ds.columns:
    sns.distplot(ds[i])
    plt.show()

# %%
ds.drop(['slope','ca','thal'],axis=1,inplace=True)

# %%
ds.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  num
# 0   63    1   4     140.0  260.0  0.0        1    112.0    1.0      3.0    2
# 1   44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0    0
# 2   60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5    2
# 3   55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5    1
# 4   66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3    0

# %%
ds.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps    56
# chol         7
# fbs          7
# restecg      0
# thalach     53
# exang       53
# oldpeak     56
# num          0
# dtype: int64

# %%
ds = ds.reset_index()

# %%
ds.head()
# Out:
#    index  age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0      0   63    1   4     140.0  260.0  0.0        1    112.0    1.0
# 1      1   44    1   4     130.0  209.0  0.0        1    127.0    0.0
# 2      2   60    1   4     132.0  218.0  0.0        1    140.0    1.0
# 3      3   55    1   4     142.0  228.0  0.0        1    149.0    1.0
# 4      4   66    1   3     110.0  213.0  1.0        2     99.0    1.0
#
#    oldpeak  num
# 0      3.0    2
# 1      0.0    0
# 2      1.5    2
# 3      2.5    1
# 4      1.3    0

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
ds.trestbps=imputer.fit_transform(ds['trestbps'].values.reshape(-1,1))

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
ds.chol=imputer.fit_transform(ds['chol'].values.reshape(-1,1))

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
ds.fbs=imputer.fit_transform(ds['fbs'].values.reshape(-1,1))

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
ds.thalach=imputer.fit_transform(ds['thalach'].values.reshape(-1,1))

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
ds.exang=imputer.fit_transform(ds['exang'].values.reshape(-1,1))

# %%
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
ds.oldpeak=imputer.fit_transform(ds['oldpeak'].values.reshape(-1,1))

# %%
ds.head()
# Out:
#    index  age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0      0   63    1   4     140.0  260.0  0.0        1    112.0    1.0
# 1      1   44    1   4     130.0  209.0  0.0        1    127.0    0.0
# 2      2   60    1   4     132.0  218.0  0.0        1    140.0    1.0
# 3      3   55    1   4     142.0  228.0  0.0        1    149.0    1.0
# 4      4   66    1   3     110.0  213.0  1.0        2     99.0    1.0
#
#    oldpeak  num
# 0      3.0    2
# 1      0.0    0
# 2      1.5    2
# 3      2.5    1
# 4      1.3    0

# %%
ds.drop(['index'],axis=1,inplace=True)

# %%
ds.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  num
# 0   63    1   4     140.0  260.0  0.0        1    112.0    1.0      3.0    2
# 1   44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0    0
# 2   60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5    2
# 3   55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5    1
# 4   66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3    0

# %%
from scipy.stats import zscore
z_score=abs(zscore(ds))
print(ds.shape)
ds_final=ds.loc[(z_score<3).all(axis=1)]
print(ds_final.shape)
# Out:
# (200, 11)
# (181, 11)

# %%
ds=ds_final
print(ds.shape)
# Out:
# (181, 11)

# %%
ds_x=ds.drop(columns=['num'])

# %%
y=pd.DataFrame(ds['num'])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_x)
x=pd.DataFrame(x,columns=ds_x.columns)

# %%
x.skew()
# Out:
# age        -0.341400
# sex         0.000000
# cp         -1.414098
# trestbps    0.516323
# chol       -0.546859
# fbs         0.695827
# restecg     0.386145
# thalach    -0.064362
# exang      -0.806441
# oldpeak     0.445245
# dtype: float64

# %%
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
max_r_score=0
for r_state in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.3)
    DT=DecisionTreeClassifier()
    DT.fit(x_train,y_train)
    y_pred=DT.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 44 is 0

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=44,stratify=y)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (126, 10) (55, 10)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (126, 1) (55, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
KNN=KNeighborsClassifier(n_neighbors=44)
SV=SVC()
DT=DecisionTreeClassifier(random_state=44)
RF=RandomForestClassifier()
AD=AdaBoostClassifier()
XG=XGBClassifier()

# %%
models= []
models.append(('KNeighborsClassifier', KNN))
models.append(('SVC', SV))
models.append(('DecisionTreeClassifier', DT))
models.append(('RandomForestClassifier', RF))
models.append(('AdaBoostClassifier', AD))
models.append(('XGBClassifier', XG))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,auc

# %%
Model= []
score= []
cvs=[]
for name,model in models:
    print('********************',name,'********************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score = ',AS)
    score.append(AS*100)
    print('\n')
    sc= cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score = ',sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'r--')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# ******************** KNeighborsClassifier ********************
#
#
# KNeighborsClassifier(n_neighbors=44)
#
#
# Accuracy_score =  0.2727272727272727
#
#
# Cross_Val_Score =  0.3374269005847953
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.25      0.08      0.12        13
#            1       0.45      0.56      0.50        16
#            2       0.19      0.42      0.26        12
#            3       0.00      0.00      0.00        11
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.27        55
#    macro avg       0.18      0.21      0.17        55
# weighted avg       0.23      0.27      0.23        55
#
#
#
# [[1 5 7 0 0]
#  [2 9 4 1 0]
#  [1 3 5 3 0]
#  [0 2 9 0 0]
#  [0 1 2 0 0]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************** SVC ********************
#
#
# SVC()
#
#
# Accuracy_score =  0.4
#
#
# ...

# %%
result = pd.DataFrame({'Model': Model, 'Accuracy_score': score,'Cross_val_score': cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score
# 0    KNeighborsClassifier       27.272727        33.742690
# 1                     SVC       40.000000        35.409357
# 2  DecisionTreeClassifier       25.454545        34.269006
# 3  RandomForestClassifier       38.181818        37.543860
# 4      AdaBoostClassifier       21.818182        29.795322
# 5           XGBClassifier       32.727273        37.573099

# %%
from sklearn.model_selection import GridSearchCV
ds=pd.read_excel("HeartDisease.xlsx")
parameters={'kernel':('linear','rbf'),'C':[1,10]}
SVR=SVC()
clf=GridSearchCV(SVR,parameters)
clf.fit(x_train,y_train)

sorted(clf.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_C',
#  'param_kernel',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
accuracy=clf.best_score_

# %%
accuracy
# Out:
# 0.316

# %%
print(clf.best_params_)
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %% [markdown]
# # SVC model is giving us better results.

# %%
import joblib
joblib.dump(SV,'SV_HeartDisease.pkl')
# Out:
# ['SV_HeartDisease.pkl']

# %%
model=joblib.load('SV_HeartDisease.pkl')

# %%
model.predict(x_test)
# Out:
# array([1, 3, 3, 2, 1, 1, 1, 1, 2, 1, 1, 1, 0, 0, 1, 2, 1, 1, 3, 1, 3, 3,
#        3, 1, 0, 0, 1, 1, 1, 2, 3, 1, 0, 1, 1, 1, 2, 1, 3, 1, 2, 1, 2, 0,
#        1, 2, 1, 0, 1, 2, 1, 2, 1, 1, 1], dtype=int64)
