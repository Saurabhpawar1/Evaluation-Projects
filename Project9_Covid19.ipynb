# %% [markdown]
# # Here we identify the number of Deaths in UnitedStates covid_19 dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('covid19.csv')
ds
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
ds.shape
# Out:
# (58, 18)

# %% [markdown]
# Observation:
#
#     There are 58 rows and 18 columns present in our dataset.

# %%
ds.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %% [markdown]
# Field description
#
# Province_State - The name of the State within the USA.
#
# Country_Region - The name of the Country (US).
#
# Last_Update - The most recent date the file was pushed.
#
# Lat - Latitude.
#
# Long_ - Longitude.
#
# Confirmed - Aggregated confirmed case count for the state.
#
# Deaths - Aggregated Death case count for the state.
#
# Recovered - Aggregated Recovered case count for the state.
#
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
#
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
#
# Incident_Rate - confirmed cases per 100,000 persons.
#
# People_Tested - Total number of people who have been tested.
#
# People_Hospitalized - Total number of people hospitalized.
#
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
#
# UID - Unique Identifier for each row entry.
#
# ISO3 - Officialy assigned country code identifiers.
#
# Testing_Rate - Total number of people tested per 100,000 persons.
#
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.

# %%
ds.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %% [markdown]
# Observation:
#
# 1. The dataset contains only two type of data numeric and object.
#
#
# 2. Province_State, Country_Region, Last_Update, ISO3 column is in object data type while rest other columns are in numeric data type.
#
#
# 3. In numeric data it consists of int and float.

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %% [markdown]
# Observation:
#
#     1. There are 14 numeric features out of which 10 are float and 4 are of int data types.
#
#     2. There are 4 categorical features which are of object data type.
#
#     3. There are no missing values present in categorical columns.

# %% [markdown]
# # To check the Missing values

# %%
ds.isnull().values.any()
# Out:
# True

# %% [markdown]
# Observation:
#
#     There are missing values present in our dataset.

# %%
ds.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [markdown]
# Observation:
#
#     1. There are 2 missing values present in each columns Lat, Long_, Incident_Rate, People_Tested, Testing_Rate.
#
#     2. There are 16 missing values present in column Recovered.
#
#     3. There are 25 missing values present in each column People_Hospitalized and Hospitalization_Rate.
#
#     4. There is 1 missing value present in Mortality_Rate column.
#
# We can also see this via visualization with the help of heatmap.

# %%
plt.figure(figsize=(14,14))
sns.heatmap(ds.isnull(),yticklabels=False,cbar=False)

# %% [markdown]
# # Exploring categorical columns.

# %%
for column in ds.columns:
    if ds[column].dtypes == object:
        print(str(column) + ' : ' + str(ds[column].unique()))
        print(ds[column].value_counts())
        print('*******************************************************************************************************')
        print('\n')
# Out:
# Province_State : ['Alabama' 'Alaska' 'American Samoa' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'Diamond Princess'
#  'District of Columbia' 'Florida' 'Georgia' 'Grand Princess' 'Guam'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Northern Mariana Islands' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Puerto Rico' 'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee'
#  'Texas' 'Utah' 'Vermont' 'Virgin Islands' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming']
# Maine                       1
# Florida                     1
# Colorado                    1
# Nevada                      1
# Puerto Rico                 1
# Louisiana                   1
# California                  1
# ...

# %% [markdown]
# Observation:
#
#     This is the summary of categorical columns.
#
#     1. This dataset is only of 1 country region which is USA.
#
#     2. This dataset was last updated on ['2020-05-21 02:32:54']

# %% [markdown]
# # Imputing Missing values in Numeric columns

# %%
#Imputing the missing values with their median

ds['Lat'].fillna(ds['Lat'].median(),inplace=True)
ds['Long_'].fillna(ds['Long_'].median(),inplace=True)
ds['Recovered'].fillna(ds['Recovered'].median(),inplace=True)
ds['Incident_Rate'].fillna(ds['Incident_Rate'].median(),inplace=True)
ds['People_Tested'].fillna(ds['People_Tested'].median(),inplace=True)
ds['People_Hospitalized'].fillna(ds['People_Hospitalized'].median(),inplace=True)
ds['Mortality_Rate'].fillna(ds['Mortality_Rate'].median(),inplace=True)
ds['Testing_Rate'].fillna(ds['Testing_Rate'].median(),inplace=True)
ds['Hospitalization_Rate'].fillna(ds['Hospitalization_Rate'].median(),inplace=True)

# %%
#Now check the null values

ds.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %% [markdown]
# Observation:
#
#     Now all the missing values are imputed. we can also see this through heatmap.

# %%
sns.heatmap(ds.isnull(),yticklabels=False,cbar=False)

# %%
ds.isnull().values.any()
# Out:
# False

# %% [markdown]
# Thus we have confirmed that there are no missing values present in our dataset now.

# %% [markdown]
# # Summary Statistics

# %%
ds.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  58.000000   58.000000      58.000000     58.000000     58.000000
# mean   36.916702  -85.301014   26756.086207   1611.017241   5904.137931
# std    10.702145   48.876367   52562.031122   4084.750891  10064.152778
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.872800  -99.697700    2596.000000     74.000000   1281.750000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.214075  -77.072550   29395.500000   1394.250000   4383.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      58.000000   5.800000e+01
# mean    20070.724138   3288.086207     391.204822   2.228466e+05
# std     41294.705318  17408.350591     396.463546   2.939333e+05
# ...

# %% [markdown]
# Observation:
#
#     1. Maximum number of deaths encountered is 28636 while the minimum is 0.
#
#     2. Maximum number of recovered cases is 61886 while the minimum is 13.
#
#     3. Maximum number of active cases is 263848 while the minimum is 0.
#
#     4. Maximum number of standard deviation is obserrved in Confirmed column.
#
#     5. In the columns COnfirmed, Deaths, Recovered, Active, FIPS, Incident_Rate, People_Tested, People_Hospitalized, Testing_Rate mean is greater than median so that columns are positively skewed.
#
#     6. In the columns Lat, UID median is greater than mean so the columns are negatively skewed.

# %% [markdown]
# # To check the correlation

# %%
ds_cor= ds.corr()
ds_cor
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.278450   0.116606  0.116727   0.061581
# Long_                -0.278450  1.000000   0.010948  0.029463  -0.021157
# Confirmed             0.116606  0.010948   1.000000  0.982191   0.793441
# Deaths                0.116727  0.029463   0.982191  1.000000   0.811694
# Recovered             0.061581 -0.021157   0.793441  0.811694   1.000000
# Active                0.116021  0.012555   0.985218  0.954378   0.680043
# FIPS                  0.037739 -0.009895  -0.096696 -0.075053  -0.054757
# Incident_Rate         0.242365  0.041919   0.713360  0.713560   0.537482
# People_Tested         0.082494 -0.077098   0.828190  0.742632   0.652961
# People_Hospitalized   0.062795  0.047996   0.858569  0.899983   0.722819
# Mortality_Rate       -0.142962  0.300753   0.382766  0.427304   0.316590
# UID                   0.774449 -0.526575   0.153972  0.120043   0.143449
# ...

# %% [markdown]
# For better understanding we can see it via visualization with  the help of heatmap.

# %%
plt.figure(figsize=(14,14))
sns.heatmap(ds_cor,annot=True,fmt='.0%',cmap='cool')
plt.show()

# %% [markdown]
# Observation:
#
#     1. Column Lat is highly positively correalted with the column UID.
#
#     2. Column Long_ is highly negatively correlated with the column UID.
#
#     3. Column Confirmed is highly positively correlated with the columns People_Hospitalized, People_Tested, Incident_Rate, Active, Recovered, Deaths.
#
#     4. Column Deaths is highly positively correlated with the columns Mortality_rate, People_Hospitalized, People_Tested, Incident_Rate, Active, Recovered, Confirmed.
#
#     5. Column Recovered is highly positively correlated with the columns People_Hospitalized, People_Tested, Incident_Rate, Deaths, Confirmed.
#
#     6. People_Hospitalized is highly positively correlated with the columns People_Tested, Incident_Rate, Active, Recovered, Deaths, Confirmed.

# %%
#checking the correlation with target variable 'Deaths'

plt.figure(figsize=(14,14))
ds.drop('Deaths', axis=1).corrwith(ds['Deaths']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("correaltion with target variable Deaths")
# Out:
# Text(0.5, 1.0, 'correaltion with target variable Deaths')

# %% [markdown]
# Observation:
#
#     1. Highest positive correlation is observed in Confirmed with respect to Deaths column.
#
#     2. Also Recovered, Active, Incident_Rate, People_Tested, People_Hospitalized are highly positively correlated with Deaths column.
#
#     3. There is some negative correlation between FIPS and Deaths column.
#
#     4. Long_ column is least correlated with Deaths column.

# %%
#checking the correlation with target variable Recovered

plt.figure(figsize=(14,14))
ds.drop('Recovered', axis=1).corrwith(ds['Recovered']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("correaltion with target variable Recovered")
# Out:
# Text(0.5, 1.0, 'correaltion with target variable Recovered')

# %% [markdown]
# Observation:
#
#     1. Highest positive correlation is observed in Deaths with respect to Recovered column.
#
#     2. Also Confirmed, Active, Incident_Rate, People_Tested, People_Hospitalized are highly positively correlated with Recovered column.
#
#     3. There is some negative correlation between FIPS and Long_ with respect to Recovered Columns.

# %% [markdown]
# # Dropping the unecessary columns

# %%
ds.drop(['Province_State','Long_','Country_Region','Last_Update'],axis=1,inplace=True)

# %%
ds.head()
# Out:
#        Lat  Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  \
# 0  32.3182      13052     522     3008.0  12530.0     1     266.194321
# 1  61.3707        401      10      352.0     39.0     2      54.815493
# 2 -14.2710          0       0     3008.0      0.0    60       0.000000
# 3  33.7298      14906     747     3773.0  10386.0     4     204.788838
# 4  34.9697       5003     107     3852.0   1044.0     5     165.782801
#
#    People_Tested  People_Hospitalized  Mortality_Rate       UID ISO3  \
# 0       164450.0               1493.0        3.999387  84000001  USA
# 1        37045.0               1493.0        2.493766  84000002  USA
# 2          124.0               1493.0        4.403318        16  ASM
# 3       165435.0               1792.0        5.011405  84000004  USA
# 4        96258.0                535.0        2.138717  84000005  USA
#
#    Testing_Rate  Hospitalization_Rate
# 0   3353.942386             11.438860
# 1   5063.940017             13.598326
# ...

# %% [markdown]
# Observation:
#
#     The columns Province_State, Long_, Country_Region, Last_Update have been dropped from our dataset.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Our 1st target variable is Deaths column.
#
# our 2nd target variable is Recovered column.

# %% [markdown]
# # Univariate Analysis

# %%
plt.subplots(figsize=(14,14))
sns.countplot(x="Deaths", data=ds)
plt.title("Number of Deaths")
plt.xticks(rotation=40)
plt.xlabel('Deaths')
plt.ylabel("Count")
plt.show()

ds['Deaths'].value_counts()
# Out:
# 0        2
# 407      2
# 377      1
# 2096     1
# 46       1
# 4525     1
# 299      1
# 3497     1
# 144      1
# 4770     1
# 1697     1
# 2123     1
# 283      1
# 538      1
# 1299     1
# 786      1
# 17       1
# 16       1
# 1037     1
# 138      1
# 11       1
# 522      1
# 393      1
# 6        1
# 5        1
# 3        1
# 2        1
# 305      1
# 125      1
# 1075     1
# 10749    1
# 376      1
# 2608     1
# 1781     1
# 747      1
# 54       1
# 107      1
# 481      1
# 28636    1
# 10       1
# 90       1
# 726      1
# 640      1
# 1426     1
# 77       1
# 73       1
# 202      1
# 3529     1
# 1864     1
# 69       1
# 5060     1
# 49       1
# 190      1
# 570      1
# 310      1
# 6066     1
# Name: Deaths, dtype: int64

# %% [markdown]
# Observation:
#
#     1. Highest number of Deaths observed is 28636.
#
#     2. Lowest number of Deaths observed is 0.

# %%
plt.subplots(figsize=(14,14))
sns.countplot(x="Recovered", data=ds)
plt.title("Number of Recovered")
plt.xticks(rotation=40)
plt.xlabel('Recovered')
plt.ylabel("Count")
plt.show()

ds['Recovered'].value_counts()
# Out:
# 3008.0     16
# 2826.0      1
# 11637.0     1
# 8362.0      1
# 1302.0      1
# 1882.0      1
# 1275.0      1
# 336.0       1
# 440.0       1
# 1100.0      1
# 473.0       1
# 1406.0      1
# 1668.0      1
# 578.0       1
# 125.0       1
# 1059.0      1
# 6264.0      1
# 3478.0      1
# 3852.0      1
# 352.0       1
# 13.0        1
# 11783.0     1
# 30341.0     1
# 7681.0      1
# 5451.0      1
# 3023.0      1
# 23945.0     1
# 28234.0     1
# 4266.0      1
# 4423.0      1
# 2993.0      1
# 3965.0      1
# 3773.0      1
# 824.0       1
# 26249.0     1
# 61886.0     1
# 528.0       1
# 4523.0      1
# 7728.0      1
# 12227.0     1
# 950.0       1
# 61.0        1
# 1030.0      1
# Name: Recovered, dtype: int64

# %% [markdown]
# Observation:
#
#     1. The maximum number of people Recovered in a Province_State are 61886.
#
#     2. In 16 Province_State 308 people have been Recovered.
#
#     3. The minimum number of people recovered in a Province_State are 13.

# %%
#Checking the column Confirmed

sns.set(style='whitegrid')
sns.violinplot(ds['Confirmed'])
plt.show()

ds['Confirmed'].value_counts()
# Out:
# 7551      1
# 154       1
# 18971     1
# 2866      1
# 49        1
# 944       1
# 2095      1
# 6317      1
# 8167      1
# 20262     1
# 1567      1
# 68126     1
# 3868      1
# 1819      1
# 14906     1
# 53009     1
# 21        1
# 787       1
# 401       1
# 22797     1
# 32908     1
# 5003      1
# 88970     1
# 11528     1
# 17670     1
# 15620     1
# 643       1
# 8194      1
# 7710      1
# 8507      1
# 29436     1
# 11967     1
# 13052     1
# 39801     1
# 150776    1
# 13356     1
# 35316     1
# 11122     1
# 47471     1
# 85997     1
# 18412     1
# 39017     1
# 5532      1
# 103       1
# 13413     1
# 478       1
# 7388      1
# 100418    1
# 29274     1
# 3801      1
# 9175      1
# 42323     1
# 4177      1
# 51673     1
# 2506      1
# 69        1
# 354370    1
# 0         1
# Name: Confirmed, dtype: int64

# %% [markdown]
# Observation:
#
#     1. The maximum number of Confirmed patients in a province_State observed are 354370.
#
#     2. The minimum number of Confirmed patients in a Province_State observed are 0.

# %%
plt.subplots(figsize=(8,6))
sns.countplot(x="ISO3", data=ds)
plt.title("Number of ISO3")
plt.xticks(rotation=40)
plt.xlabel('ISO3')
plt.ylabel("Count")
plt.show()

ds['ISO3'].value_counts()
# Out:
# USA    53
# ASM     1
# VIR     1
# GUM     1
# MNP     1
# PRI     1
# Name: ISO3, dtype: int64

# %% [markdown]
# Observation:
#
#     The maximum number of ISO3 observed is USA which is seen 53 times.

# %%
#checking the Active column

sns.set(style='whitegrid')
sns.violinplot(ds['Active'])
plt.show()

ds['Active'].value_counts()
# Out:
# 27655.0     1
# 744.0       1
# 82500.0     1
# 82904.0     1
# 248.0       1
# 548.0       1
# 2.0         1
# 66.0        1
# 1108.0      1
# 7899.0      1
# 967.0       1
# 10386.0     1
# 116082.0    1
# 6.0         1
# 4152.0      1
# 27310.0     1
# 22.0        1
# 3716.0      1
# 646.0       1
# 7832.0      1
# 761.0       1
# 48.0        1
# 24.0        1
# 100.0       1
# 49.0        1
# 1044.0      1
# 0.0         1
# 39.0        1
# 29224.0     1
# 6865.0      1
# 2251.0      1
# 3317.0      1
# 4965.0      1
# 37207.0     1
# 45375.0     1
# 11788.0     1
# 2741.0      1
# 38104.0     1
# 3919.0      1
# 19715.0     1
# 4657.0      1
# 6085.0      1
# 263848.0    1
# 19906.0     1
# 5204.0      1
# 3197.0      1
# 6324.0      1
# 6675.0      1
# 10984.0     1
# 2403.0      1
# 10888.0     1
# 27410.0     1
# 63356.0     1
# 18020.0     1
# 17934.0     1
# 6459.0      1
# 95893.0     1
# 12530.0     1
# Name: Active, dtype: int64

# %% [markdown]
# Observation:
#
#     1. The maximum Active patients in a Province_State observed are 263848.
#
#     2. The maximum number of Active Patients are in the range of 0 to 2500.

# %%
#Checking the People_Tested column

sns.set(style='whitegrid')
sns.violinplot(ds['People_Tested'])
plt.show()

ds['People_Tested'].value_counts()
# Out:
# 138654.5     2
# 71203.0      1
# 402940.0     1
# 167713.0     1
# 40419.0      1
# 142246.0     1
# 120680.0     1
# 102149.0     1
# 37269.0      1
# 285970.0     1
# 18840.0      1
# 3817.0       1
# 30389.0      1
# 642713.0     1
# 91171.0      1
# 72135.0      1
# 771348.0     1
# 179664.0     1
# 50888.0      1
# 96258.0      1
# 531343.0     1
# 1380120.0    1
# 80641.0      1
# 153986.0     1
# 164450.0     1
# 1383.0       1
# 46304.0      1
# 59200.0      1
# 1505836.0    1
# 29726.0      1
# 354013.0     1
# 770241.0     1
# 190718.0     1
# 437072.0     1
# 131837.0     1
# 289528.0     1
# 165435.0     1
# 195738.0     1
# 161984.0     1
# 110748.0     1
# 135063.0     1
# 25058.0      1
# 215330.0     1
# 120528.0     1
# 167338.0     1
# 37045.0      1
# 144371.0     1
# 349700.0     1
# 212626.0     1
# 277603.0     1
# 293120.0     1
# 2866.0       1
# 489953.0     1
# 4972.0       1
# 45412.0      1
# 38567.0      1
# 124.0        1
# ...

# %% [markdown]
# Observation:
#
#     1. The maximum number of People_Tested in a Province_State are 1505836.
#
#     2. The minimum number of People_Tested in a Province_State are 124.

# %%
#Checking the Mortality_Rate column

sns.set(style='whitegrid')
sns.violinplot(ds['Mortality_Rate'])
plt.show()

ds['Mortality_Rate'].value_counts()
# Out:
# 4.403318    2
# 4.028152    1
# 2.643857    1
# 2.338902    1
# 4.448217    1
# 1.167315    1
# 7.384755    1
# 3.072626    1
# 3.783256    1
# 2.493766    1
# 1.240784    1
# 5.720339    1
# 6.818029    1
# 7.129119    1
# 4.763099    1
# 2.138717    1
# 4.479975    1
# 3.266683    1
# 4.263712    1
# 2.912621    1
# 3.999387    1
# 4.361479    1
# 2.759662    1
# 4.603894    1
# 3.788477    1
# 5.102870    1
# 4.912099    1
# 8.695652    1
# 6.050414    1
# 4.013194    1
# 5.466238    1
# 2.516005    1
# 1.101269    1
# 2.374515    1
# 6.367425    1
# 7.001732    1
# 5.404917    1
# 3.583062    1
# 8.080819    1
# 5.016185    1
# 5.551700    1
# 4.435967    1
# 1.397713    1
# 4.506164    1
# 5.390015    1
# 9.523810    1
# 4.415327    1
# 5.011405    1
# 4.066421    1
# 9.545549    1
# 3.586073    1
# 5.698118    1
# 3.347280    1
# 3.246753    1
# 9.044775    1
# 1.656528    1
# 0.000000    1
# Name: Mortality_Rate, dtype: int64

# %% [markdown]
# Observation:
#
#     1. The maximum number of Mortality_Rate observed in a Provinve_State is 9.545549
#
#     2. The maximum number of Mortality_Rate observed is in the range of 3 to 5.8

# %%
#Checking the Testing_Rate column

sns.set(style='whitegrid')
sns.violinplot(ds['Testing_Rate'])
plt.show()

ds['Testing_Rate'].value_counts()
# Out:
# 3469.782532     2
# 3729.047853     1
# 2772.553734     1
# 3742.560000     1
# 2781.307250     1
# 2646.841883     1
# 2272.859351     1
# 3270.352122     1
# 3510.159838     1
# 5982.117023     1
# 6783.862680     1
# 2158.119598     1
# 4663.552976     1
# 7740.670204     1
# 222.857246      1
# 2639.281471     1
# 7108.491647     1
# 3648.523075     1
# 6151.487891     1
# 2491.072892     1
# 3255.240955     1
# 3446.671231     1
# 1289.294104     1
# 2656.380746     1
# 3353.942386     1
# 4376.471997     1
# 3189.670370     1
# 2967.179419     1
# 2959.947483     1
# 4054.904509     1
# 5183.833360     1
# 4015.775919     1
# 3591.383953     1
# 3435.108895     1
# 97.702058       1
# 3027.479921     1
# 2444.055121     1
# 2623.237570     1
# 3561.716796     1
# 5604.065930     1
# 3795.082856     1
# 5063.940017     1
# 3849.298999     1
# 5727.106946     1
# 2476.905835     1
# 7768.396797     1
# 3492.893832     1
# 2731.606784     1
# 5071.986102     1
# 2907.481174     1
# ...

# %% [markdown]
# Observation:
#
#     1. The maximum number of Testing_Rate in a Province State is 11377.
#
#     2. The maximum number of Testing_rate is observed in the range of 2800 to 4800.

# %%
#Checking the Hospitalization_Rate column

sns.set(style='whitegrid')
sns.violinplot(ds['Hospitalization_Rate'])
plt.show()

ds['Hospitalization_Rate'].value_counts()
# Out:
# 13.598326    26
# 7.972229      1
# 13.061686     1
# 17.856335     1
# 28.054438     1
# 8.579409      1
# 15.738420     1
# 21.562209     1
# 18.411936     1
# 18.030711     1
# 9.901758      1
# 14.992826     1
# 16.359364     1
# 8.933819      1
# 12.752722     1
# 8.228329      1
# 11.438860     1
# 9.402795      1
# 6.778043      1
# 17.658649     1
# 17.468043     1
# 8.184176      1
# 17.348774     1
# 18.819911     1
# 10.693584     1
# 15.885351     1
# 12.022005     1
# 19.021310     1
# 11.126086     1
# 16.111235     1
# 24.611240     1
# 12.699285     1
# 10.000000     1
# Name: Hospitalization_Rate, dtype: int64

# %% [markdown]
# observation:
#
#     1. The maximum number of Hospitalization_Rate in a Province_State observed is 28.054438.
#
#     2. The maximum number of Hospitalization_Rate falls in the range of 13 to 17.

# %%
#checking the mean of Deaths

red_shift = ds['Deaths'].hist()
mean_val = np.mean(ds['Deaths'])
plt.axvline(mean_val,linewidth=4, color='red', label='Deaths_mean')
plt.xlabel('Deaths')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
#checking the mean of Recovered

red_shift = ds['Recovered'].hist()
mean_val = np.mean(ds['Recovered'])
plt.axvline(mean_val,linewidth=4, color='red', label='Recovered_mean')
plt.xlabel('Recovered')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
#checking the mean of Confirmed

red_shift = ds['Confirmed'].hist()
mean_val = np.mean(ds['Confirmed'])
plt.axvline(mean_val,linewidth=4, color='red', label='Confirmed_mean')
plt.xlabel('Confirmed')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
#checking the mean of Active

red_shift = ds['Active'].hist()
mean_val = np.mean(ds['Active'])
plt.axvline(mean_val,linewidth=4, color='red', label='Active_mean')
plt.xlabel('Active')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
#checking the mean of People_Tested

red_shift = ds['People_Tested'].hist()
mean_val = np.mean(ds['People_Tested'])
plt.axvline(mean_val,linewidth=4, color='red', label='People_Tested_mean')
plt.xlabel('People_Tested')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
#checking the mean of Confirmed

red_shift = ds['Confirmed'].hist()
mean_val = np.mean(ds['Confirmed'])
plt.axvline(mean_val,linewidth=4, color='red', label='Confirmed_mean')
plt.xlabel('Confirmed')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#Exploring Deaths vs Recovered via Scatter plot

sns.set(style='white')
plt.scatter(ds['Deaths'],ds['Recovered'])
plt.xlabel('No of Deaths')
plt.ylabel('No of Recovered')
plt.title("Scatter plot of No of Deaths vs Recovered")
plt.show()

# %% [markdown]
# Observation:
#
#     As the number of Recovered are incresing number of Deaths decreasing.

# %%
#Exploring Confirmed vs Deaths via Scatter plot

sns.set(style='white')
plt.scatter(ds['Confirmed'],ds['Deaths'])
plt.xlabel('No of Confirmed')
plt.ylabel('No of Deaths')
plt.title("Scatter plot of No of Confirmed vs Deaths")
plt.show()

# %% [markdown]
# Observation:
#
#     As the number of Confirmed Patients are increasing number of Deaths are also increasing.

# %%
#Exploring Deaths vs Active via Scatter plot

sns.set(style='white')
plt.scatter(ds['Deaths'],ds['Active'])
plt.xlabel('No of Deaths')
plt.ylabel('No of Active')
plt.title("Scatter plot of No of Deaths vs Active")
plt.show()

# %% [markdown]
# Observation:
#
#     As the number of Active cases are increasing number of Deaths are also increasing.

# %%
#Exploring Deaths vs Mortality_Rate via Scatter plot

sns.set(style='white')
plt.scatter(ds['Deaths'],ds['Mortality_Rate'])
plt.xlabel('No of Deaths')
plt.ylabel('Mortality_Rate')
plt.title("Scatter plot of No of Deaths vs Mortality_Rate")
plt.show()

# %% [markdown]
# Observation:
#
#     As the Mortality_Rate is increasing the number of Deaths is decreasing.

# %%
#Exploring Recovered vs People_Tested via Scatter plot

sns.set(style='white')
plt.scatter(ds['People_Tested'],ds['Recovered'])
plt.xlabel('No of People_Tested')
plt.ylabel('No of Recovered')
plt.title("Scatter plot of No of People_Tested vs Recovered")
plt.show()

# %% [markdown]
# Observation:
#
#     As the number of People_Tested increases number of Recovered cases also increases.

# %%
#Exploring Mortality_Rate vs Recovered via Scatter plot

sns.set(style='white')
plt.scatter(ds['Mortality_Rate'],ds['Recovered'])
plt.xlabel('Mortality_Rate')
plt.ylabel('No of Recovered')
plt.title("Scatter plot of No of Mortality_Rate vs Recovered")
plt.show()

# %% [markdown]
# Observation:
#
#     As the Mortality_Rate increases No. of Recovered cases also increases.

# %%
#Exploring Testing_Rate vs Recovered via Scatter plot

sns.set(style='white')
plt.scatter(ds['Testing_Rate'],ds['Recovered'])
plt.xlabel('Testing_Rate')
plt.ylabel('No of Recovered')
plt.title("Scatter plot Testing_Rate vs Recovered")
plt.show()

# %% [markdown]
# Observation:
#
#     As the Testing_Rate increases No. of Recovered caases also increases.

# %%
#Barplot of ISO3 vs Deaths

plt.figure(figsize=(16,6))
sns.barplot(x='ISO3',y='Deaths',data=ds)
plt.xticks()
plt.show()

# %% [markdown]
# Observation:
#
#     The maximum no. of Deaths have been observed in ISO3 USA.

# %%
#Barplot of Confirmed vs Deaths
plt.figure(figsize=(16,6))
sns.barplot(x='Confirmed',y='Deaths',data=ds)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# Observation:
#
#     AS the no. of Confirmed cases are increasing Deaths are also increasing.

# %%
#Barplot of Confirmed vs Recovered

plt.figure(figsize=(14,14))
sns.barplot(x='Confirmed',y='Recovered',data=ds)
plt.xticks(rotation=50)
plt.show()

# %%
#Barplot of FIPS vs Deaths
plt.figure(figsize=(14,14))
sns.barplot(x='FIPS',y='Deaths',data=ds)
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# Observation:
#
#     Maximum number of Deaths have been observed in FIPS 36.

# %%
#Barplot of FIPS vs Recovered
plt.figure(figsize=(14,14))
sns.barplot(x='FIPS',y='Recovered',data=ds)
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# Observation:
#
#     Maximum no. of Recovered cases have been observed in FIPS 36.

# %% [markdown]
# # Multivariate Analysis

# %%
#scatter plot between Deaths and Recovered with respect to ISO3
plt.figure(figsize=(8,4))
sns.lmplot(x='Deaths',y='Recovered',fit_reg=False,data=ds,hue='ISO3',markers=['*','+','d','D','x','X'])
plt.xlabel('Deaths')
plt.title('correaltion between Deaths and Recoverd')
plt.ylabel('Recovered')
plt.show()

# %% [markdown]
# Observation:
#
#     The maximum data present is of ISO3 USA.

# %%
#scatter plot between Confirmed and Active with respect to ISO3
plt.figure(figsize=(8,4))
sns.lmplot(x='Confirmed',y='Active',fit_reg=False,data=ds,hue='ISO3',markers=['*','+','d','D','x','X'])
plt.xlabel('Confirmed')
plt.title('correaltion between Confirmed and Active')
plt.ylabel('Active')
plt.show()

# %%
sns.pairplot(ds)

# %% [markdown]
# # Converting the Categoric column to numeric variable

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds['ISO3']=le.fit_transform(ds['ISO3'].astype(str))

# %%
ds.head()
# Out:
#        Lat  Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  \
# 0  32.3182      13052     522     3008.0  12530.0     1     266.194321
# 1  61.3707        401      10      352.0     39.0     2      54.815493
# 2 -14.2710          0       0     3008.0      0.0    60       0.000000
# 3  33.7298      14906     747     3773.0  10386.0     4     204.788838
# 4  34.9697       5003     107     3852.0   1044.0     5     165.782801
#
#    People_Tested  People_Hospitalized  Mortality_Rate       UID  ISO3  \
# 0       164450.0               1493.0        3.999387  84000001     4
# 1        37045.0               1493.0        2.493766  84000002     4
# 2          124.0               1493.0        4.403318        16     0
# 3       165435.0               1792.0        5.011405  84000004     4
# 4        96258.0                535.0        2.138717  84000005     4
#
#    Testing_Rate  Hospitalization_Rate
# 0   3353.942386             11.438860
# 1   5063.940017             13.598326
# ...

# %% [markdown]
# # Removing Skewness

# %%
for col in ds.describe().columns:
    sns.distplot(ds[col],color='r')
    plt.show()

# %%
ds.skew()
# Out:
# Lat                    -2.267089
# Confirmed               4.708614
# Deaths                  5.489201
# Recovered               3.797239
# Active                  4.180953
# FIPS                    5.269070
# Incident_Rate           2.012296
# People_Tested           2.847892
# People_Hospitalized     7.015366
# Mortality_Rate          0.497497
# UID                    -3.027480
# ISO3                   -4.126625
# Testing_Rate            1.333601
# Hospitalization_Rate    1.114428
# dtype: float64

# %%
#Removing skewness via log method

for col in ds.columns:
    if ds.skew().loc[col]>0.55:
        ds[col]=np.log1p(ds[col])

# %%
ds.skew()
# Out:
# Lat                    -2.267089
# Confirmed              -1.374603
# Deaths                 -0.568714
# Recovered              -0.861845
# Active                 -0.994488
# FIPS                    3.421540
# Incident_Rate          -1.783566
# People_Tested          -1.619104
# People_Hospitalized    -0.074706
# Mortality_Rate          0.497497
# UID                    -3.027480
# ISO3                   -4.126625
# Testing_Rate           -2.953045
# Hospitalization_Rate   -0.035832
# dtype: float64

# %%
ds.isnull().sum()
# Out:
# Lat                     0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %% [markdown]
# # Removing Outliers

# %%
plt.figure(figsize=(18,14))

for i in range(len(ds.columns)):
        plt.subplot(7,2,i+1)
        plt.boxplot(ds[ds.columns[i]], vert=False)
        plt.title(ds.columns[i])
plt.show()

# %% [markdown]
# Observation:
#
#     We can see that there are some outliers present in our dataset.

# %%
from scipy.stats import zscore
z_score=abs(zscore(ds))
print(ds.shape)
ds_final=ds.loc[(z_score<3).all(axis=1)]
print(ds_final.shape)
# Out:
# (58, 14)
# (50, 14)

# %%
ds=ds_final
print(ds.shape)
# Out:
# (50, 14)

# %% [markdown]
# # Model Training

# %%
ds.head()
# Out:
#        Lat  Confirmed    Deaths  Recovered     Active      FIPS  \
# 0  32.3182   9.476773  6.259581   8.009363   9.435961  0.693147
# 1  61.3707   5.996452  2.397895   5.866468   3.688879  1.098612
# 3  33.7298   9.609586  6.617403   8.235891   9.248310  1.609438
# 4  34.9697   8.517993  4.682131   8.256607   6.951772  1.791759
# 5  36.1162  11.362079  8.159947   8.009363  11.320566  1.945910
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 0       5.587976      12.010368             7.309212        3.999387
# 1       4.022051      10.519916             7.309212        2.493766
# 3       5.326851      12.016340             7.491645        5.011405
# 4       5.116692      11.474798             6.284134        2.138717
# 5       5.387457      14.137682             7.309212        4.066421
#
#         UID  ISO3  Testing_Rate  Hospitalization_Rate
# 0  84000001     4      8.118190              2.520825
# 1  84000002     4      8.530098              2.680907
# ...

# %%
x=ds.drop(columns=['Deaths'],axis=1)

# %%
y=ds['Deaths']

# %%
#checking the shape of input and target variable
print(x.shape,'\t\t',y.shape)
# Out:
# (50, 13) 		 (50,)

# %%
#scaling input variables

from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
max_r_score=0
for r_state in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 53 is 0.9975714112813503

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=53)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(x_train,y_train)
    print('score of',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('Mean absolute error:',mean_absolute_error(y_test,predm))
    print('Mean squared error:',mean_squared_error(y_test,predm))
    print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predm)))
    print("r2_score:",r2_score(y_test,predm))
    print('********************************************************************************************')
    print('\n')
# Out:
# score of LinearRegression() is: 0.9930051888454907
# Error:
# Mean absolute error: 0.0784072681284663
# Mean squared error: 0.0077677918319514535
# Root Mean Squared Error: 0.08813507719376805
# r2_score: 0.9975714112813503
# ********************************************************************************************
#
#
# score of DecisionTreeRegressor() is: 1.0
# Error:
# Mean absolute error: 0.6579451391228499
# Mean squared error: 0.794679665091191
# Root Mean Squared Error: 0.8914480720104739
# r2_score: 0.7515445687354435
# ********************************************************************************************
#
#
# score of KNeighborsRegressor() is: 0.903736377785931
# Error:
# Mean absolute error: 0.4000499064928322
# Mean squared error: 0.36567092575156995
# Root Mean Squared Error: 0.6047073058526496
# r2_score: 0.8856735216093765
# ********************************************************************************************
#
#
# score of SVR() is: 0.9352942504616218
# ...

# %% [markdown]
# # Testing our Ridge() Model

# %%
#Ridge model is giving best results so finding its parameters using GridSearchCV

from sklearn.model_selection import GridSearchCV
ridge=Ridge()
parameters={'alpha':[0.001,0.01,0.1,1]}
clf=GridSearchCV(ridge,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.1}

# %%
#Using Ridge model with best results

ridge=Ridge(alpha=0.1,random_state=53)
ridge.fit(x_train,y_train)
print('SCore:',ridge.score(x_train,y_train))
predrd=ridge.predict(x_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y_test,predrd))
print('Mean squared error:',mean_squared_error(y_test,predrd))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrd)))
print('\n')
print("r2_score:",r2_score(y_test,predrd))
# Out:
# SCore: 0.9929529299767523
#
#
# Mean absolute error: 0.07181496908933291
# Mean squared error: 0.007029106108371026
# Root Mean Squared Error: 0.08383976448184373
#
#
# r2_score: 0.9978023602889609

# %%
#Cross validate Ridge
from sklearn.model_selection import cross_val_score
score=cross_val_score(ridge,x,y,cv=4,scoring='r2')
print("Score:",score)
print('Mean Score:',score.mean())
print("Standard deviation:",score.std())
# Out:
# Score: [0.98985425 0.98425087 0.99214175 0.9751157 ]
# Mean Score: 0.9853406430644256
# Standard deviation: 0.006564390186080678

# %% [markdown]
# # Testing our DecisionTreeRegressor() Model

# %%
#Finding parameters using GridSearchCV
DTR=DecisionTreeRegressor()
parameters={'criterion':['mse', 'friedman_mse', 'mae']}
clf=GridSearchCV(DTR,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'criterion': 'mae'}

# %%
#Using DecisionTreeRegressor model with best results
DTR=DecisionTreeRegressor(criterion='mae',random_state=53)
DTR.fit(x_train,y_train)
print('Score:',DTR.score(x_train,y_train))
preddt=DTR.predict(x_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y_test,preddt))
print('Mean squared error:',mean_squared_error(y_test,preddt))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,preddt)))
print('\n')
print("r2_score:",r2_score(y_test,preddt))
# Out:
# Score: 1.0
#
#
# Mean absolute error: 0.48019085369972475
# Mean squared error: 0.48706960197799204
# Root Mean Squared Error: 0.6979037197049405
#
#
# r2_score: 0.847718403614353

# %%
#Cross validating 

score=cross_val_score(DTR,x,y,cv=4,scoring='r2')
print("Score:",score)
print('Mean Score:',score.mean())
print("Standard deviation:",score.std())
# Out:
# Score: [0.82246116 0.45431311 0.87882373 0.52124553]
# Mean Score: 0.6692108828040231
# Standard deviation: 0.1840502564805641

# %% [markdown]
# # Our Ridge() Model is working best because it gives the best r2_score and also it is not suffering from overfitting and underfitting.So we save Ridge() as our final Model.

# %%
#saving our Ridge() Model

import joblib
joblib.dump(ridge,'Covid19.pkl')
# Out:
# ['Covid19.pkl']

# %%
model=joblib.load('Covid19.pkl')

# %%
model.predict(x_test)
# Out:
# array([2.48920768, 6.58371006, 5.98258094, 8.69503279, 5.89626652,
#        5.98355557, 6.47054843, 8.1763436 , 7.56834409, 3.76609062])

# %% [markdown]
# # Here we identify number of Recovered in United_States Covid19 dataset

# %%
ds1=pd.read_csv('covid19.csv')
ds1
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %% [markdown]
# Now we do all the changes as we did above

# %%
ds1.drop(['Province_State','Long_','Country_Region','Last_Update'],axis=1,inplace=True)

# %%
#Imputing the missing values with their median

ds1['Lat'].fillna(ds1['Lat'].median(),inplace=True)
ds1['Recovered'].fillna(ds1['Recovered'].median(),inplace=True)
ds1['Incident_Rate'].fillna(ds1['Incident_Rate'].median(),inplace=True)
ds1['People_Tested'].fillna(ds1['People_Tested'].median(),inplace=True)
ds1['People_Hospitalized'].fillna(ds1['People_Hospitalized'].median(),inplace=True)
ds1['Mortality_Rate'].fillna(ds1['Mortality_Rate'].median(),inplace=True)
ds1['Testing_Rate'].fillna(ds1['Testing_Rate'].median(),inplace=True)
ds1['Hospitalization_Rate'].fillna(ds1['Hospitalization_Rate'].median(),inplace=True)

# %%
le=LabelEncoder()
ds1['ISO3']=le.fit_transform(ds1['ISO3'].astype(str))

# %%
ds1.skew()
# Out:
# Lat                    -2.267089
# Confirmed               4.708614
# Deaths                  5.489201
# Recovered               3.797239
# Active                  4.180953
# FIPS                    5.269070
# Incident_Rate           2.012296
# People_Tested           2.847892
# People_Hospitalized     7.015366
# Mortality_Rate          0.497497
# UID                    -3.027480
# ISO3                   -4.126625
# Testing_Rate            1.333601
# Hospitalization_Rate    1.114428
# dtype: float64

# %%
#Removing skewness via log method

for col in ds1.columns:
    if ds1.skew().loc[col]>0.55:
        ds1[col]=np.log1p(ds1[col])

# %%
ds1.skew()
# Out:
# Lat                    -2.267089
# Confirmed              -1.374603
# Deaths                 -0.568714
# Recovered              -0.861845
# Active                 -0.994488
# FIPS                    3.421540
# Incident_Rate          -1.783566
# People_Tested          -1.619104
# People_Hospitalized    -0.074706
# Mortality_Rate          0.497497
# UID                    -3.027480
# ISO3                   -4.126625
# Testing_Rate           -2.953045
# Hospitalization_Rate   -0.035832
# dtype: float64

# %%
from scipy.stats import zscore
z_score=abs(zscore(ds1))
print(ds1.shape)
ds1_final=ds1.loc[(z_score<3).all(axis=1)]
print(ds1_final.shape)
# Out:
# (58, 14)
# (50, 14)

# %%
ds1=ds1_final
print(ds1.shape)
# Out:
# (50, 14)

# %%
x1=ds1.drop(columns=['Recovered'],axis=1)

# %%
y1=ds1['Recovered']

# %%
#checking the shape of input and target variable
print(x1.shape,'\t\t',y1.shape)
# Out:
# (50, 13) 		 (50,)

# %%
#scaling input variables

ss=StandardScaler()
x1=ss.fit_transform(x1)

# %%
max_r_score1=0
for r_state in range(1,100):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,random_state=r_state,test_size=0.20)
    LR=linear_model.LinearRegression()
    LR.fit(x1_train,y1_train)
    y1_pred=LR.predict(x1_test)
    r2_scr=r2_score(y1_test,y1_pred)
    if r2_scr>max_r_score1:
        max_r_score1=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score1)
# Out:
# max r2 score corresponding to 36 is 0.8500969449653762

# %%
 x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.20,random_state=36)

# %%
model1=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for d in model1:
    d.fit(x1_train,y1_train)
    print('score of',d,'is:',d.score(x1_train,y1_train))
    predd=d.predict(x1_test)
    print('Error:')
    print('Mean absolute error:',mean_absolute_error(y1_test,predd))
    print('Mean squared error:',mean_squared_error(y1_test,predd))
    print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y1_test,predd)))
    print("r2_score:",r2_score(y1_test,predd))
    print('********************************************************************************************')
    print('\n')
# Out:
# score of LinearRegression() is: 0.7501734103015161
# Error:
# Mean absolute error: 0.40519974507930784
# Mean squared error: 0.22886574931765513
# Root Mean Squared Error: 0.47839915271419026
# r2_score: 0.8500969449653762
# ********************************************************************************************
#
#
# score of DecisionTreeRegressor() is: 1.0
# Error:
# Mean absolute error: 0.7921228813910238
# Mean squared error: 1.0788817873037675
# Root Mean Squared Error: 1.0386923448758865
# r2_score: 0.29335133622996024
# ********************************************************************************************
#
#
# score of KNeighborsRegressor() is: 0.550457148021144
# Error:
# Mean absolute error: 0.8272617538406879
# Mean squared error: 0.8769974451684475
# Root Mean Squared Error: 0.9364814174175842
# r2_score: 0.4255820423970763
# ********************************************************************************************
#
#
# score of SVR() is: 0.6503082296066949
# ...

# %% [markdown]
# # Testing our LinearRegression() model

# %%
#Finding parameters using GridSearchCV
LR=LinearRegression()
parameters={'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
clr=GridSearchCV(LR,parameters)
clr.fit(x1,y1)
clr.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
#Using LinearRegression model with best results
LR=LinearRegression(copy_X=True, fit_intercept=True, normalize=False)
LR.fit(x1_train,y1_train)
print('Score:',LR.score(x1_train,y1_train))
predlr=LR.predict(x1_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y1_test,predlr))
print('Mean squared error:',mean_squared_error(y1_test,predlr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y1_test,predlr)))
print('\n')
print("r2_score:",r2_score(y1_test,predlr))
# Out:
# Score: 0.7501734103015161
#
#
# Mean absolute error: 0.40519974507930784
# Mean squared error: 0.22886574931765513
# Root Mean Squared Error: 0.47839915271419026
#
#
# r2_score: 0.8500969449653762

# %%
score=cross_val_score(LR,x1,y1,cv=4,scoring='r2')
print("Score:",score)
print('Mean Score:',score.mean())
print("Standard deviation:",score.std())
# Out:
# Score: [-6.90937564  0.57799344  0.68631715  0.38740419]
# Mean Score: -1.3144152155812667
# Standard deviation: 3.232023821428101

# %% [markdown]
# # Using ensemble techniques to boostup our score

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=20,random_state=36)
rf.fit(x1_train,y1_train)
print('Score:',rf.score(x1_train,y1_train))
predrf=rf.predict(x1_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y1_test,predrf))
print('Mean squared error:',mean_squared_error(y1_test,predrf))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y1_test,predrf)))
print('\n')
print("r2_score:",r2_score(y1_test,predrf))
# Out:
# Score: 0.8908123230500029
#
#
# Mean absolute error: 0.8366516636343393
# Mean squared error: 1.11028660827713
# Root Mean Squared Error: 1.053701384775179
#
#
# r2_score: 0.27278172884764973

# %%
from sklearn.ensemble import AdaBoostRegressor
lasso=Lasso()

adb=AdaBoostRegressor(base_estimator=lasso,n_estimators=20,learning_rate=0.1,random_state=36)
adb.fit(x1_train,y1_train)
print('Score:',adb.score(x1_train,y1_train))
predadb=adb.predict(x1_test)
print('\n')
print('Mean absolute error:',mean_absolute_error(y1_test,predadb))
print('Mean squared error:',mean_squared_error(y1_test,predadb))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y1_test,predadb)))
print('\n')
print("r2_score:",r2_score(y1_test,predadb))
# Out:
# Score: 0.054729013278753125
#
#
# Mean absolute error: 1.0995256057577625
# Mean squared error: 1.576762613442345
# Root Mean Squared Error: 1.255692085442265
#
#
# r2_score: -0.032751879755174906

# %%
#CrossValidating our RandomForestModel()

score=cross_val_score(rf,x1,y1,cv=4,scoring='r2')
print("Score:",score)
print('Mean Score:',score.mean())
print("Standard deviation:",score.std())
# Out:
# Score: [-0.23646917  0.28505613  0.39806175  0.49205311]
# Mean Score: 0.2346754546379423
# Standard deviation: 0.28171519522417976

# %% [markdown]
# # Our LinearRegressionModel is performimg best. so we save LR as our final model

# %%
#saving our LineaRegression() Model

import joblib
joblib.dump(LR,'Covid19_.pkl')
# Out:
# ['Covid19_.pkl']

# %%
model1=joblib.load('Covid19_.pkl')

# %%
model1.predict(x1_test)
# Out:
# array([6.70346368, 6.4386949 , 9.91611164, 8.71629089, 6.81291929,
#        8.49778877, 7.4154672 , 6.96977071, 7.66310444, 6.94920607])
